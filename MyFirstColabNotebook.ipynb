# %% [markdown]
# <a href="https://colab.research.google.com/github/Ikenergy/hello-world/blob/master/MyFirstColabNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Question 1:
# Write a function to find the nth fibonacci number in the fibonacci sequence.
# In the Fibonacci sequence, the first two numbers are 0 and 1 and each number after that is the sum of the previous two numbers in the sequence.
# So, the sequence looks like this: 0,1,1,2,3,5,8,13,21... and so on.
# The '0' in the sequence is considered to be the 0th element, the fisrt '1' is considered to be the 1st element, the '2' is the 3rd element etc.
# And the problem specifically states that the function or method needs to return the nth element in the Fibonacci sequence, where the input to that function or method is n.

# %%
# Solution:

def nth_fibonacci(n):
    a, b = 0, 1
    my_fibonacci = []

    while True:
        my_fibonacci.append(a)
        a, b = b, a+b
        if len(my_fibonacci)-1 == n:
            break
    return my_fibonacci[-1]

# %% [markdown]
# #Question 2:
# Write a function that will return the list of duplicate numbers in an array of 100 numbers.
# Your solution should return a list of only those numbers that appear more than once in the provided array.

# %%
#Solutions:

# SOLUTION 1 - when the list is generated by random sampling

import random
my_double_list=[]
my_dict = {}
myList1= random.sample(range(1, 100), 40)
myList2= random.sample(range(1, 100), 40)
myList3= random.sample(range(1, 100), 20)
my_new_list = myList1 + myList2 + myList3

def duplicate_list():
    for num in my_new_list:
        if num not in my_dict:
            my_dict[num]=1
        else:
            my_dict[num]+=1
    for key, value in my_dict.items():
        if value >= 2:
            my_double_list.append(key)

    #print('The numbers are: ', my_new_list)
    #print('Each number appear as follows: ', my_dict)
    print('From an array of %d numbers, these numbers appear more than once: ' %(len(my_new_list)) )
    print(my_double_list)

duplicate_list()




#  SOLUTION 2 - user generated numbers

my_double_list=[]
my_dict = {}
my_list=[]
num_lenght = int(input("How many numbers to process: "))

while len(my_list) != num_lenght:
    my_list.append(input('Please enter number: '))

def duplicate_list():
    for num in my_list:
        if num not in my_dict:
            my_dict[num]=1
        else:
            my_dict[num]+=1
    for key, value in my_dict.items():
        if value >= 2:
            my_double_list.append(key)

    #print('The numbers are: ', my_list)
    #print('Each number appear as follows: ', my_dict)
    print('From an array of %d numbers, these numbers appear more than once: ' %(len(my_list)) )
    print(my_double_list)

duplicate_list()

# %% [markdown]
# #Question 3:
# Given 3 int values a, b, c, return their sum.
# However,, if one of the values is 13, then it does not count towards the sum and values to its right do not count.
# So for example, if b is 13, then both b and c do not count. Hence, luckySum(1,2,3) ----6, luckySum(1,2,13) ----3, luckySum(1,13,3) ----1.

# %%
#Solution:

# SOLUTION 1 - enables user to enter the 3 numbers interactively.

def luckySum():
    strangeSum = 0
    a = int(input("PLEASE ENTER FIRST NUMBER: "))
    b = int(input("PLEASE ENTER SECOND NUMBER: "))
    c = int(input("PLEASE ENTER THIRD NUMBER: "))
    myList = [a, b, c]
    for num in myList:
        if num == 13:
            break
        else:
            strangeSum+=num
    print(strangeSum)

luckySum() # FUNCTION CALL


# SOLUTION 2 - Allows function call with arguments

def luckySum(*args):
    mySum = 0
    for num in args:
        if num == 13:
            break
        else:
            mySum+=num
    print(mySum)

luckySum(12, 15, 13) # FUNCTION CALL
